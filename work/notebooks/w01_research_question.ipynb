# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
# ### My lane: Refresh / Content Opportunity Scoring
#
# I chose this lane because I want to use data and ML to identify which pages should be reviewed first. The dataset has signals such as impressions, CTR, position, content age, and trend that can help us rank pages by their review priority.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# ### My question
#
# Which pages should be reviewed first for a possible content refresh?
#
# Decision: Which pages should get priority?
# Action: The content team can review the highest-priority pages and decide whether to refresh, improve, protect, or monitor them.
# Cost of a wrong decision: We may waste time on a page that does not need attention or miss a page that does.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# The dataset contains 30,000 pages. 16,726 pages have at least 500 impressions in the last 90 days, and 16,262 pages have a downward trend. This makes the refresh opportunity worth investigating because there are many pages with measurable search activity and performance changes.

# %%
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

print("Total pages:", len(df))

visible = (df["impressions_90d"] >= 500).sum()
declining = (df["trend_direction"].str.lower() == "down").sum()

print("Pages with 500+ impressions:", visible)
print("Pages with a downward trend:", declining)
# Out:
# Total pages: 30000
# Pages with 500+ impressions: 16726
# Pages with a downward trend: 16262

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# ### What I can claim
#
# I can use the data to find observed patterns and rank pages for review. The results can support content decisions and help prioritize work.
#
# ### What I can't claim
#
# I cannot claim that the model will guarantee better rankings or traffic. I also cannot claim that the data proves what causes Google rankings to change.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
